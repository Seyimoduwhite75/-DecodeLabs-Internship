# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import openpyxl
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel(r"C:\Users\Pelumi Akinrinde\OneDrive - Creditville\week 4.xlsx")

# %%
df.head()
# Out:
#      OrderID       Date Month    YEAR CustomerID  Product  Quantity  \
# 0  ORD200000 2023-01-04   Jan  2023.0     C72649  Monitor       5.0
# 1  ORD200001 2024-08-23   Aug  2024.0     C75739    Phone       2.0
# 2  ORD200002 2024-02-27   Feb  2024.0     C81728   Tablet       5.0
# 3  ORD200003 2023-10-15   Oct  2023.0     C33540    Chair       1.0
# 4  ORD200004 2025-05-08   May  2025.0     C81840  Printer       4.0
#
#    UnitPrice ShippingAddress PaymentMethod OrderStatus TrackingNumber  \
# 0     570.62     928 Main St    Debit Card     Shipped    TRK37947903
# 1     151.35     823 Main St        Online     Shipped    TRK91186779
# 2     550.68     512 Main St   Credit Card   Cancelled    TRK42903982
# 3     273.19     275 Main St    Debit Card    Returned    TRK62788070
# 4     626.01     668 Main St        Online   Delivered    TRK29241424
#
#    ItemsInCart CouponCode ReferralSource  TotalPrice
# 0          7.0     SAVE10      Instagram     2853.10
# ...

# %%
pd.pivot_table(df, index="Product", values="TotalPrice", aggfunc=np.sum).plot(kind="bar")
plt.title("Total Price by Product")
plt.xlabel("Product")
plt.ylabel("Total Price")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Chair'),
#   Text(1, 0, 'Desk'),
#   Text(2, 0, 'Laptop'),
#   Text(3, 0, 'Monitor'),
#   Text(4, 0, 'Phone'),
#   Text(5, 0, 'Printer'),
#   Text(6, 0, 'Tablet')])

# %%
sns.barplot(x="Product", y="TotalPrice", data=df, hue="YEAR")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sns.barplot(x="Product", y="TotalPrice", data=df, hue="Year")
#
# File c:\Users\Pelumi Akinrinde\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
#    2347     legend=legend,
#    2348 )
#    2350 if ax is None:
# ...
